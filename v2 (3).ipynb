# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/My Drive/uni_assignments/COS30082/face_recognition_dataset/11-785-fall-20-homework-2-part-2.zip" -d "/content/data"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data/verification_data/00064099.jpg
#   inflating: /content/data/verification_data/00064100.jpg
#   inflating: /content/data/verification_data/00064101.jpg
#   inflating: /content/data/verification_data/00064102.jpg
#   inflating: /content/data/verification_data/00064103.jpg
#   inflating: /content/data/verification_data/00064104.jpg
#   inflating: /content/data/verification_data/00064105.jpg
#   inflating: /content/data/verification_data/00064106.jpg
#   inflating: /content/data/verification_data/00064107.jpg
#   inflating: /content/data/verification_data/00064108.jpg
#   inflating: /content/data/verification_data/00064109.jpg
#   inflating: /content/data/verification_data/00064110.jpg
#   inflating: /content/data/verification_data/00064111.jpg
#   inflating: /content/data/verification_data/00064112.jpg
#   inflating: /content/data/verification_data/00064113.jpg
#   inflating: /content/data/verification_data/00064114.jpg
#   inflating: /content/data/verification_data/00064115.jpg
#   inflating: /content/data/verification_data/00064116.jpg
#   inflating: /content/data/verification_data/00064117.jpg
#   inflating: /content/data/verification_data/00064118.jpg
#   inflating: /content/data/verification_data/00064119.jpg
#   inflating: /content/data/verification_data/00064120.jpg
#   inflating: /content/data/verification_data/00064121.jpg
#   inflating: /content/data/verification_data/00064122.jpg
#   inflating: /content/data/verification_data/00064123.jpg
#   inflating: /content/data/verification_data/00064124.jpg
#   inflating: /content/data/verification_data/00064125.jpg
#   inflating: /content/data/verification_data/00064126.jpg
#   inflating: /content/data/verification_data/00064127.jpg
#   inflating: /content/data/verification_data/00064128.jpg
#   inflating: /content/data/verification_data/00064129.jpg
#   inflating: /content/data/verification_data/00064130.jpg
#   inflating: /content/data/verification_data/00064131.jpg
#   inflating: /content/data/verification_data/00064132.jpg
#   inflating: /content/data/verification_data/00064133.jpg
#   inflating: /content/data/verification_data/00064134.jpg
#   inflating: /content/data/verification_data/00064135.jpg
#   inflating: /content/data/verification_data/00064136.jpg
#   inflating: /content/data/verification_data/00064137.jpg
#   inflating: /content/data/verification_data/00064138.jpg
#   inflating: /content/data/verification_data/00064139.jpg
#   inflating: /content/data/verification_data/00064140.jpg
#   inflating: /content/data/verification_data/00064141.jpg
#   inflating: /content/data/verification_data/00064142.jpg
#   inflating: /content/data/verification_data/00064143.jpg
#   inflating: /content/data/verification_data/00064144.jpg
#   inflating: /content/data/verification_data/00064145.jpg
#   inflating: /content/data/verification_data/00064146.jpg
#   inflating: /content/data/verification_data/00064147.jpg
#   inflating: /content/data/verification_data/00064148.jpg
#   inflating: /content/data/verification_data/00064149.jpg
#   inflating: /content/data/verification_data/00064150.jpg
#   inflating: /content/data/verification_data/00064151.jpg
#   inflating: /content/data/verification_data/00064152.jpg
#   inflating: /content/data/verification_data/00064153.jpg
#   inflating: /content/data/verification_data/00064154.jpg
#   inflating: /content/data/verification_data/00064155.jpg
#   inflating: /content/data/verification_data/00064156.jpg
#   inflating: /content/data/verification_data/00064157.jpg
#   inflating: /content/data/verification_data/00064158.jpg
#   inflating: /content/data/verification_data/00064159.jpg
#   inflating: /content/data/verification_data/00064160.jpg
#   inflating: /content/data/verification_data/00064161.jpg
#   inflating: /content/data/verification_data/00064162.jpg
#   inflating: /content/data/verification_data/00064163.jpg
#   inflating: /content/data/verification_data/00064164.jpg
#   inflating: /content/data/verification_data/00064165.jpg
#   inflating: /content/data/verification_data/00064166.jpg
#   inflating: /content/data/verification_data/00064167.jpg
#   inflating: /content/data/verification_data/00064168.jpg
#   inflating: /content/data/verification_data/00064169.jpg
#   inflating: /content/data/verification_data/00064170.jpg
#   inflating: /content/data/verification_data/00064171.jpg
#   inflating: /content/data/verification_data/00064172.jpg
#   inflating: /content/data/verification_data/00064173.jpg
#   inflating: /content/data/verification_data/00064174.jpg
#   inflating: /content/data/verification_data/00064175.jpg
#   inflating: /content/data/verification_data/00064176.jpg
#   inflating: /content/data/verification_data/00064177.jpg
#   inflating: /content/data/verification_data/00064178.jpg
#   inflating: /content/data/verification_data/00064179.jpg
#   inflating: /content/data/verification_data/00064180.jpg
#   inflating: /content/data/verification_data/00064181.jpg
#   inflating: /content/data/verification_data/00064182.jpg
#   inflating: /content/data/verification_data/00064183.jpg
#   inflating: /content/data/verification_data/00064184.jpg
#   inflating: /content/data/verification_data/00064185.jpg
#   inflating: /content/data/verification_data/00064186.jpg
#   inflating: /content/data/verification_data/00064187.jpg
#   inflating: /content/data/verification_data/00064188.jpg
#   inflating: /content/data/verification_data/00064189.jpg
#   inflating: /content/data/verification_data/00064190.jpg
#   inflating: /content/data/verification_data/00064191.jpg
#   inflating: /content/data/verification_data/00064192.jpg
#   inflating: /content/data/verification_data/00064193.jpg
#   inflating: /content/data/verification_data/00064194.jpg
#   inflating: /content/data/verification_data/00064195.jpg
#   inflating: /content/data/verification_data/00064196.jpg
#   inflating: /content/data/verification_data/00064197.jpg
#   inflating: /content/data/verification_data/00064198.jpg
#   inflating: /content/data/verification_data/00064199.jpg
#   inflating: /content/data/verification_data/00064200.jpg
#   inflating: /content/data/verification_data/00064201.jpg
#   inflating: /content/data/verification_data/00064202.jpg
#   inflating: /content/data/verification_data/00064203.jpg
#   inflating: /content/data/verification_data/00064204.jpg
#   inflating: /content/data/verification_data/00064205.jpg
#   inflating: /content/data/verification_data/00064206.jpg
#   inflating: /content/data/verification_data/00064207.jpg
#   inflating: /content/data/verification_data/00064208.jpg
#   inflating: /content/data/verification_data/00064209.jpg
#   inflating: /content/data/verification_data/00064210.jpg
#   inflating: /content/data/verification_data/00064211.jpg
#   inflating: /content/data/verification_data/00064212.jpg
#   inflating: /content/data/verification_data/00064213.jpg
#   inflating: /content/data/verification_data/00064214.jpg
#   inflating: /content/data/verification_data/00064215.jpg
#   inflating: /content/data/verification_data/00064216.jpg
#   inflating: /content/data/verification_data/00064217.jpg
#   inflating: /content/data/verification_data/00064218.jpg
#   inflating: /content/data/verification_data/00064219.jpg
#   inflating: /content/data/verification_data/00064220.jpg
#   inflating: /content/data/verification_data/00064221.jpg
#   inflating: /content/data/verification_data/00064222.jpg
#   inflating: /content/data/verification_data/00064223.jpg
#   inflating: /content/data/verification_data/00064224.jpg
#   inflating: /content/data/verification_data/00064225.jpg
#   inflating: /content/data/verification_data/00064226.jpg
#   inflating: /content/data/verification_data/00064227.jpg
#   inflating: /content/data/verification_data/00064228.jpg
#   inflating: /content/data/verification_data/00064229.jpg
#   inflating: /content/data/verification_data/00064230.jpg
#   inflating: /content/data/verification_data/00064231.jpg
#   inflating: /content/data/verification_data/00064232.jpg
#   inflating: /content/data/verification_data/00064233.jpg
#   inflating: /content/data/verification_data/00064234.jpg
#   inflating: /content/data/verification_data/00064235.jpg
#   inflating: /content/data/verification_data/00064236.jpg
#   inflating: /content/data/verification_data/00064237.jpg
#   inflating: /content/data/verification_data/00064238.jpg
#   inflating: /content/data/verification_data/00064239.jpg
#   inflating: /content/data/verification_data/00064240.jpg
#   inflating: /content/data/verification_data/00064241.jpg
#   inflating: /content/data/verification_data/00064242.jpg
#   inflating: /content/data/verification_data/00064243.jpg
#   inflating: /content/data/verification_data/00064244.jpg
#   inflating: /content/data/verification_data/00064245.jpg
#   inflating: /content/data/verification_data/00064246.jpg
#   inflating: /content/data/verification_data/00064247.jpg
#   inflating: /content/data/verification_data/00064248.jpg
#   inflating: /content/data/verification_data/00064249.jpg
#   inflating: /content/data/verification_data/00064250.jpg
#   inflating: /content/data/verification_data/00064251.jpg
#   inflating: /content/data/verification_data/00064252.jpg
#   inflating: /content/data/verification_data/00064253.jpg
#   inflating: /content/data/verification_data/00064254.jpg
#   inflating: /content/data/verification_data/00064255.jpg
#   inflating: /content/data/verification_data/00064256.jpg
#   inflating: /content/data/verification_data/00064257.jpg
#   inflating: /content/data/verification_data/00064258.jpg
#   inflating: /content/data/verification_data/00064259.jpg
#   inflating: /content/data/verification_data/00064260.jpg
#   inflating: /content/data/verification_data/00064261.jpg
#   inflating: /content/data/verification_data/00064262.jpg
#   inflating: /content/data/verification_data/00064263.jpg
#   inflating: /content/data/verification_data/00064264.jpg
#   inflating: /content/data/verification_data/00064265.jpg
#   inflating: /content/data/verification_data/00064266.jpg
#   inflating: /content/data/verification_data/00064267.jpg
#   inflating: /content/data/verification_data/00064268.jpg
#   inflating: /content/data/verification_data/00064269.jpg
#   inflating: /content/data/verification_data/00064270.jpg
#   inflating: /content/data/verification_data/00064271.jpg
#   inflating: /content/data/verification_data/00064272.jpg
#   inflating: /content/data/verification_data/00064273.jpg
#   inflating: /content/data/verification_data/00064274.jpg
#   inflating: /content/data/verification_data/00064275.jpg
#   inflating: /content/data/verification_data/00064276.jpg
#   inflating: /content/data/verification_data/00064277.jpg
#   inflating: /content/data/verification_data/00064278.jpg
#   inflating: /content/data/verification_data/00064279.jpg
#   inflating: /content/data/verification_data/00064280.jpg
#   inflating: /content/data/verification_data/00064281.jpg
#   inflating: /content/data/verification_data/00064282.jpg
#   inflating: /content/data/verification_data/00064283.jpg
#   inflating: /content/data/verification_data/00064284.jpg
#   inflating: /content/data/verification_data/00064285.jpg
#   inflating: /content/data/verification_data/00064286.jpg
#   inflating: /content/data/verification_data/00064287.jpg
#   inflating: /content/data/verification_data/00064288.jpg
#   inflating: /content/data/verification_data/00064289.jpg
#   inflating: /content/data/verification_data/00064290.jpg
#   inflating: /content/data/verification_data/00064291.jpg
#   inflating: /content/data/verification_data/00064292.jpg
#   inflating: /content/data/verification_data/00064293.jpg
#   inflating: /content/data/verification_data/00064294.jpg
#   inflating: /content/data/verification_data/00064295.jpg
#   inflating: /content/data/verification_data/00064296.jpg
#   inflating: /content/data/verification_data/00064297.jpg
#   inflating: /content/data/verification_data/00064298.jpg
#   inflating: /content/data/verification_data/00064299.jpg
#   inflating: /content/data/verification_data/00064300.jpg
#   inflating: /content/data/verification_data/00064301.jpg
#   inflating: /content/data/verification_data/00064302.jpg
#   inflating: /content/data/verification_data/00064303.jpg
#   inflating: /content/data/verification_data/00064304.jpg
#   inflating: /content/data/verification_data/00064305.jpg
#   inflating: /content/data/verification_data/00064306.jpg
#   inflating: /content/data/verification_data/00064307.jpg
#   inflating: /content/data/verification_data/00064308.jpg
#   inflating: /content/data/verification_data/00064309.jpg
#   inflating: /content/data/verification_data/00064310.jpg
#   inflating: /content/data/verification_data/00064311.jpg
#   inflating: /content/data/verification_data/00064312.jpg
#   inflating: /content/data/verification_data/00064313.jpg
#   inflating: /content/data/verification_data/00064314.jpg
#   inflating: /content/data/verification_data/00064315.jpg
#   inflating: /content/data/verification_data/00064316.jpg
#   inflating: /content/data/verification_data/00064317.jpg
#   inflating: /content/data/verification_data/00064318.jpg
#   inflating: /content/data/verification_data/00064319.jpg
#   inflating: /content/data/verification_data/00064320.jpg
#   inflating: /content/data/verification_data/00064321.jpg
#   inflating: /content/data/verification_data/00064322.jpg
#   inflating: /content/data/verification_data/00064323.jpg
#   inflating: /content/data/verification_data/00064324.jpg
#   inflating: /content/data/verification_data/00064325.jpg
#   inflating: /content/data/verification_data/00064326.jpg
#   inflating: /content/data/verification_data/00064327.jpg
#   inflating: /content/data/verification_data/00064328.jpg
#   inflating: /content/data/verification_data/00064329.jpg
#   inflating: /content/data/verification_data/00064330.jpg
#   inflating: /content/data/verification_data/00064331.jpg
#   inflating: /content/data/verification_data/00064332.jpg
#   inflating: /content/data/verification_data/00064333.jpg
#   inflating: /content/data/verification_data/00064334.jpg
#   inflating: /content/data/verification_data/00064335.jpg
#   inflating: /content/data/verification_data/00064336.jpg
#   inflating: /content/data/verification_data/00064337.jpg
#   inflating: /content/data/verification_data/00064338.jpg
#   inflating: /content/data/verification_data/00064339.jpg
#   inflating: /content/data/verification_data/00064340.jpg
#   inflating: /content/data/verification_data/00064341.jpg
#   inflating: /content/data/verification_data/00064342.jpg
#   inflating: /content/data/verification_data/00064343.jpg
#   inflating: /content/data/verification_data/00064344.jpg
#   inflating: /content/data/verification_data/00064345.jpg
#   inflating: /content/data/verification_data/00064346.jpg
#   inflating: /content/data/verification_data/00064347.jpg
#   inflating: /content/data/verification_data/00064348.jpg
#   inflating: /content/data/verification_data/00064349.jpg
#   inflating: /content/data/verification_data/00064350.jpg
#   inflating: /content/data/verification_data/00064351.jpg
#   inflating: /content/data/verification_data/00064352.jpg
#   inflating: /content/data/verification_data/00064353.jpg
#   inflating: /content/data/verification_data/00064354.jpg
#   inflating: /content/data/verification_data/00064355.jpg
#   inflating: /content/data/verification_data/00064356.jpg
#   inflating: /content/data/verification_data/00064357.jpg
#   inflating: /content/data/verification_data/00064358.jpg
#   inflating: /content/data/verification_data/00064359.jpg
#   inflating: /content/data/verification_data/00064360.jpg
#   inflating: /content/data/verification_data/00064361.jpg
#   inflating: /content/data/verification_data/00064362.jpg
#   inflating: /content/data/verification_data/00064363.jpg
#   inflating: /content/data/verification_data/00064364.jpg
#   inflating: /content/data/verification_data/00064365.jpg
#   inflating: /content/data/verification_data/00064366.jpg
#   inflating: /content/data/verification_data/00064367.jpg
#   inflating: /content/data/verification_data/00064368.jpg
#   inflating: /content/data/verification_data/00064369.jpg
#   inflating: /content/data/verification_data/00064370.jpg
#   inflating: /content/data/verification_data/00064371.jpg
#   inflating: /content/data/verification_data/00064372.jpg
#   inflating: /content/data/verification_data/00064373.jpg
#   inflating: /content/data/verification_data/00064374.jpg
#   inflating: /content/data/verification_data/00064375.jpg
#   inflating: /content/data/verification_data/00064376.jpg
#   inflating: /content/data/verification_data/00064377.jpg
#   inflating: /content/data/verification_data/00064378.jpg
#   inflating: /content/data/verification_data/00064379.jpg
#   inflating: /content/data/verification_data/00064380.jpg
#   inflating: /content/data/verification_data/00064381.jpg
#   inflating: /content/data/verification_data/00064382.jpg
#   inflating: /content/data/verification_data/00064383.jpg
#   inflating: /content/data/verification_data/00064384.jpg
#   inflating: /content/data/verification_data/00064385.jpg
#   inflating: /content/data/verification_data/00064386.jpg
#   inflating: /content/data/verification_data/00064387.jpg
#   inflating: /content/data/verification_data/00064388.jpg
#   inflating: /content/data/verification_data/00064389.jpg
#   inflating: /content/data/verification_data/00064390.jpg
#   inflating: /content/data/verification_data/00064391.jpg
#   inflating: /content/data/verification_data/00064392.jpg
#   inflating: /content/data/verification_data/00064393.jpg
#   inflating: /content/data/verification_data/00064394.jpg
#   inflating: /content/data/verification_data/00064395.jpg
#   inflating: /content/data/verification_data/00064396.jpg
#   inflating: /content/data/verification_data/00064397.jpg
#   inflating: /content/data/verification_data/00064398.jpg
#   inflating: /content/data/verification_data/00064399.jpg
#   inflating: /content/data/verification_data/00064400.jpg
#   inflating: /content/data/verification_data/00064401.jpg
#   inflating: /content/data/verification_data/00064402.jpg
#   inflating: /content/data/verification_data/00064403.jpg
#   inflating: /content/data/verification_data/00064404.jpg
#   inflating: /content/data/verification_data/00064405.jpg
#   inflating: /content/data/verification_data/00064406.jpg
#   inflating: /content/data/verification_data/00064407.jpg
#   inflating: /content/data/verification_data/00064408.jpg
#   inflating: /content/data/verification_data/00064409.jpg
#   inflating: /content/data/verification_data/00064410.jpg
#   inflating: /content/data/verification_data/00064411.jpg
#   inflating: /content/data/verification_data/00064412.jpg
#   inflating: /content/data/verification_data/00064413.jpg
#   inflating: /content/data/verification_data/00064414.jpg
#   inflating: /content/data/verification_data/00064415.jpg
#   inflating: /content/data/verification_data/00064416.jpg
#   inflating: /content/data/verification_data/00064417.jpg
#   inflating: /content/data/verification_data/00064418.jpg
#   inflating: /content/data/verification_data/00064419.jpg
#   inflating: /content/data/verification_data/00064420.jpg
#   inflating: /content/data/verification_data/00064421.jpg
#   inflating: /content/data/verification_data/00064422.jpg
#   inflating: /content/data/verification_data/00064423.jpg
#   inflating: /content/data/verification_data/00064424.jpg
#   inflating: /content/data/verification_data/00064425.jpg
#   inflating: /content/data/verification_data/00064426.jpg
#   inflating: /content/data/verification_data/00064427.jpg
#   inflating: /content/data/verification_data/00064428.jpg
#   inflating: /content/data/verification_data/00064429.jpg
#   inflating: /content/data/verification_data/00064430.jpg
#   inflating: /content/data/verification_data/00064431.jpg
#   inflating: /content/data/verification_data/00064432.jpg
#   inflating: /content/data/verification_data/00064433.jpg
#   inflating: /content/data/verification_data/00064434.jpg
#   inflating: /content/data/verification_data/00064435.jpg
#   inflating: /content/data/verification_data/00064436.jpg
#   inflating: /content/data/verification_data/00064437.jpg
#   inflating: /content/data/verification_data/00064438.jpg
#   inflating: /content/data/verification_data/00064439.jpg
#   inflating: /content/data/verification_data/00064440.jpg
#   inflating: /content/data/verification_data/00064441.jpg
#   inflating: /content/data/verification_data/00064442.jpg
#   inflating: /content/data/verification_data/00064443.jpg
#   inflating: /content/data/verification_data/00064444.jpg
#   inflating: /content/data/verification_data/00064445.jpg
#   inflating: /content/data/verification_data/00064446.jpg
#   inflating: /content/data/verification_data/00064447.jpg
#   inflating: /content/data/verification_data/00064448.jpg
#   inflating: /content/data/verification_data/00064449.jpg
#   inflating: /content/data/verification_data/00064450.jpg
#   inflating: /content/data/verification_data/00064451.jpg
#   inflating: /content/data/verification_data/00064452.jpg
#   inflating: /content/data/verification_data/00064453.jpg
#   inflating: /content/data/verification_data/00064454.jpg
#   inflating: /content/data/verification_data/00064455.jpg
#   inflating: /content/data/verification_data/00064456.jpg
#   inflating: /content/data/verification_data/00064457.jpg
#   inflating: /content/data/verification_data/00064458.jpg
#   inflating: /content/data/verification_data/00064459.jpg
#   inflating: /content/data/verification_data/00064460.jpg
#   inflating: /content/data/verification_data/00064461.jpg
#   inflating: /content/data/verification_data/00064462.jpg
#   inflating: /content/data/verification_data/00064463.jpg
#   inflating: /content/data/verification_data/00064464.jpg
#   inflating: /content/data/verification_data/00064465.jpg
#   inflating: /content/data/verification_data/00064466.jpg
#   inflating: /content/data/verification_data/00064467.jpg
#   inflating: /content/data/verification_data/00064468.jpg
#   inflating: /content/data/verification_data/00064469.jpg
#   inflating: /content/data/verification_data/00064470.jpg
#   inflating: /content/data/verification_data/00064471.jpg
#   inflating: /content/data/verification_data/00064472.jpg
#   inflating: /content/data/verification_data/00064473.jpg
#   inflating: /content/data/verification_data/00064474.jpg
#   inflating: /content/data/verification_data/00064475.jpg
#   inflating: /content/data/verification_data/00064476.jpg
#   inflating: /content/data/verification_data/00064477.jpg
#   inflating: /content/data/verification_data/00064478.jpg
#   inflating: /content/data/verification_data/00064479.jpg
#   inflating: /content/data/verification_data/00064480.jpg
#   inflating: /content/data/verification_data/00064481.jpg
#   inflating: /content/data/verification_data/00064482.jpg
#   inflating: /content/data/verification_data/00064483.jpg
#   inflating: /content/data/verification_data/00064484.jpg
#   inflating: /content/data/verification_data/00064485.jpg
#   inflating: /content/data/verification_data/00064486.jpg
#   inflating: /content/data/verification_data/00064487.jpg
#   inflating: /content/data/verification_data/00064488.jpg
#   inflating: /content/data/verification_data/00064489.jpg
#   inflating: /content/data/verification_data/00064490.jpg
#   inflating: /content/data/verification_data/00064491.jpg
#   inflating: /content/data/verification_data/00064492.jpg
#   inflating: /content/data/verification_data/00064493.jpg
#   inflating: /content/data/verification_data/00064494.jpg
#   inflating: /content/data/verification_data/00064495.jpg
#   inflating: /content/data/verification_data/00064496.jpg
#   inflating: /content/data/verification_data/00064497.jpg
#   inflating: /content/data/verification_data/00064498.jpg
#   inflating: /content/data/verification_data/00064499.jpg
#   inflating: /content/data/verification_data/00064500.jpg
#   inflating: /content/data/verification_data/00064501.jpg
#   inflating: /content/data/verification_data/00064502.jpg
#   inflating: /content/data/verification_data/00064503.jpg
#   inflating: /content/data/verification_data/00064504.jpg
#   inflating: /content/data/verification_data/00064505.jpg
#   inflating: /content/data/verification_data/00064506.jpg
#   inflating: /content/data/verification_data/00064507.jpg
#   inflating: /content/data/verification_data/00064508.jpg
#   inflating: /content/data/verification_data/00064509.jpg
#   inflating: /content/data/verification_data/00064510.jpg
#   inflating: /content/data/verification_data/00064511.jpg
#   inflating: /content/data/verification_data/00064512.jpg
#   inflating: /content/data/verification_data/00064513.jpg
#   inflating: /content/data/verification_data/00064514.jpg
#   inflating: /content/data/verification_data/00064515.jpg
#   inflating: /content/data/verification_data/00064516.jpg
#   inflating: /content/data/verification_data/00064517.jpg
#   inflating: /content/data/verification_data/00064518.jpg
#   inflating: /content/data/verification_data/00064519.jpg
#   inflating: /content/data/verification_data/00064520.jpg
#   inflating: /content/data/verification_data/00064521.jpg
#   inflating: /content/data/verification_data/00064522.jpg
#   inflating: /content/data/verification_data/00064523.jpg
#   inflating: /content/data/verification_data/00064524.jpg
#   inflating: /content/data/verification_data/00064525.jpg
#   inflating: /content/data/verification_data/00064526.jpg
#   inflating: /content/data/verification_data/00064527.jpg
#   inflating: /content/data/verification_data/00064528.jpg
#   inflating: /content/data/verification_data/00064529.jpg
#   inflating: /content/data/verification_data/00064530.jpg
#   inflating: /content/data/verification_data/00064531.jpg
#   inflating: /content/data/verification_data/00064532.jpg
#   inflating: /content/data/verification_data/00064533.jpg
#   inflating: /content/data/verification_data/00064534.jpg
#   inflating: /content/data/verification_data/00064535.jpg
#   inflating: /content/data/verification_data/00064536.jpg
#   inflating: /content/data/verification_data/00064537.jpg
#   inflating: /content/data/verification_data/00064538.jpg
#   inflating: /content/data/verification_data/00064539.jpg
#   inflating: /content/data/verification_data/00064540.jpg
#   inflating: /content/data/verification_data/00064541.jpg
#   inflating: /content/data/verification_data/00064542.jpg
#   inflating: /content/data/verification_data/00064543.jpg
#   inflating: /content/data/verification_data/00064544.jpg
#   inflating: /content/data/verification_data/00064545.jpg
#   inflating: /content/data/verification_data/00064546.jpg
#   inflating: /content/data/verification_data/00064547.jpg
#   inflating: /content/data/verification_data/00064548.jpg
#   inflating: /content/data/verification_data/00064549.jpg
#   inflating: /content/data/verification_data/00064550.jpg
#   inflating: /content/data/verification_data/00064551.jpg
#   inflating: /content/data/verification_data/00064552.jpg
#   inflating: /content/data/verification_data/00064553.jpg
#   inflating: /content/data/verification_data/00064554.jpg
#   inflating: /content/data/verification_data/00064555.jpg
#   inflating: /content/data/verification_data/00064556.jpg
#   inflating: /content/data/verification_data/00064557.jpg
#   inflating: /content/data/verification_data/00064558.jpg
#   inflating: /content/data/verification_data/00064559.jpg
#   inflating: /content/data/verification_data/00064560.jpg
#   inflating: /content/data/verification_data/00064561.jpg
#   inflating: /content/data/verification_data/00064562.jpg
#   inflating: /content/data/verification_data/00064563.jpg
#   inflating: /content/data/verification_data/00064564.jpg
#   inflating: /content/data/verification_data/00064565.jpg
#   inflating: /content/data/verification_data/00064566.jpg
#   inflating: /content/data/verification_data/00064567.jpg
#   inflating: /content/data/verification_data/00064568.jpg
#   inflating: /content/data/verification_data/00064569.jpg
#   inflating: /content/data/verification_data/00064570.jpg
#   inflating: /content/data/verification_data/00064571.jpg
#   inflating: /content/data/verification_data/00064572.jpg
#   inflating: /content/data/verification_data/00064573.jpg
#   inflating: /content/data/verification_data/00064574.jpg
#   inflating: /content/data/verification_data/00064575.jpg
#   inflating: /content/data/verification_data/00064576.jpg
#   inflating: /content/data/verification_data/00064577.jpg
#   inflating: /content/data/verification_data/00064578.jpg
#   inflating: /content/data/verification_data/00064579.jpg
#   inflating: /content/data/verification_data/00064580.jpg
#   inflating: /content/data/verification_data/00064581.jpg
#   inflating: /content/data/verification_data/00064582.jpg
#   inflating: /content/data/verification_data/00064583.jpg
#   inflating: /content/data/verification_data/00064584.jpg
#   inflating: /content/data/verification_data/00064585.jpg
#   inflating: /content/data/verification_data/00064586.jpg
#   inflating: /content/data/verification_data/00064587.jpg
#   inflating: /content/data/verification_data/00064588.jpg
#   inflating: /content/data/verification_data/00064589.jpg
#   inflating: /content/data/verification_data/00064590.jpg
#   inflating: /content/data/verification_data/00064591.jpg
#   inflating: /content/data/verification_data/00064592.jpg
#   inflating: /content/data/verification_data/00064593.jpg
#   inflating: /content/data/verification_data/00064594.jpg
#   inflating: /content/data/verification_data/00064595.jpg
#   inflating: /content/data/verification_data/00064596.jpg
#   inflating: /content/data/verification_data/00064597.jpg
#   inflating: /content/data/verification_data/00064598.jpg
#   inflating: /content/data/verification_data/00064599.jpg
#   inflating: /content/data/verification_data/00064600.jpg
#   inflating: /content/data/verification_data/00064601.jpg
#   inflating: /content/data/verification_data/00064602.jpg
#   inflating: /content/data/verification_data/00064603.jpg
#   inflating: /content/data/verification_data/00064604.jpg
#   inflating: /content/data/verification_data/00064605.jpg
#   inflating: /content/data/verification_data/00064606.jpg
#   inflating: /content/data/verification_data/00064607.jpg
#   inflating: /content/data/verification_data/00064608.jpg
#   inflating: /content/data/verification_data/00064609.jpg
#   inflating: /content/data/verification_data/00064610.jpg
#   inflating: /content/data/verification_data/00064611.jpg
#   inflating: /content/data/verification_data/00064612.jpg
#   inflating: /content/data/verification_data/00064613.jpg
#   inflating: /content/data/verification_data/00064614.jpg
#   inflating: /content/data/verification_data/00064615.jpg
#   inflating: /content/data/verification_data/00064616.jpg
#   inflating: /content/data/verification_data/00064617.jpg
#   inflating: /content/data/verification_data/00064618.jpg
#   inflating: /content/data/verification_data/00064619.jpg
#   inflating: /content/data/verification_data/00064620.jpg
#   inflating: /content/data/verification_data/00064621.jpg
#   inflating: /content/data/verification_data/00064622.jpg
#   inflating: /content/data/verification_data/00064623.jpg
#   inflating: /content/data/verification_data/00064624.jpg
#   inflating: /content/data/verification_data/00064625.jpg
#   inflating: /content/data/verification_data/00064626.jpg
#   inflating: /content/data/verification_data/00064627.jpg
#   inflating: /content/data/verification_data/00064628.jpg
#   inflating: /content/data/verification_data/00064629.jpg
#   inflating: /content/data/verification_data/00064630.jpg
#   inflating: /content/data/verification_data/00064631.jpg
#   inflating: /content/data/verification_data/00064632.jpg
#   inflating: /content/data/verification_data/00064633.jpg
#   inflating: /content/data/verification_data/00064634.jpg
#   inflating: /content/data/verification_data/00064635.jpg
#   inflating: /content/data/verification_data/00064636.jpg
#   inflating: /content/data/verification_data/00064637.jpg
#   inflating: /content/data/verification_data/00064638.jpg
#   inflating: /content/data/verification_data/00064639.jpg
#   inflating: /content/data/verification_data/00064640.jpg
#   inflating: /content/data/verification_data/00064641.jpg
#   inflating: /content/data/verification_data/00064642.jpg
#   inflating: /content/data/verification_data/00064643.jpg
#   inflating: /content/data/verification_data/00064644.jpg
#   inflating: /content/data/verification_data/00064645.jpg
#   inflating: /content/data/verification_data/00064646.jpg
#   inflating: /content/data/verification_data/00064647.jpg
#   inflating: /content/data/verification_data/00064648.jpg
#   inflating: /content/data/verification_data/00064649.jpg
#   inflating: /content/data/verification_data/00064650.jpg
#   inflating: /content/data/verification_data/00064651.jpg
#   inflating: /content/data/verification_data/00064652.jpg
#   inflating: /content/data/verification_data/00064653.jpg
#   inflating: /content/data/verification_data/00064654.jpg
#   inflating: /content/data/verification_data/00064655.jpg
#   inflating: /content/data/verification_data/00064656.jpg
#   inflating: /content/data/verification_data/00064657.jpg
#   inflating: /content/data/verification_data/00064658.jpg
#   inflating: /content/data/verification_data/00064659.jpg
#   inflating: /content/data/verification_data/00064660.jpg
#   inflating: /content/data/verification_data/00064661.jpg
#   inflating: /content/data/verification_data/00064662.jpg
#   inflating: /content/data/verification_data/00064663.jpg
#   inflating: /content/data/verification_data/00064664.jpg
#   inflating: /content/data/verification_data/00064665.jpg
#   inflating: /content/data/verification_data/00064666.jpg
#   inflating: /content/data/verification_data/00064667.jpg
#   inflating: /content/data/verification_data/00064668.jpg
#   inflating: /content/data/verification_data/00064669.jpg
#   inflating: /content/data/verification_data/00064670.jpg
#   inflating: /content/data/verification_data/00064671.jpg
#   inflating: /content/data/verification_data/00064672.jpg
#   inflating: /content/data/verification_data/00064673.jpg
#   inflating: /content/data/verification_data/00064674.jpg
#   inflating: /content/data/verification_data/00064675.jpg
#   inflating: /content/data/verification_data/00064676.jpg
#   inflating: /content/data/verification_data/00064677.jpg
#   inflating: /content/data/verification_data/00064678.jpg
#   inflating: /content/data/verification_data/00064679.jpg
#   inflating: /content/data/verification_data/00064680.jpg
#   inflating: /content/data/verification_data/00064681.jpg
#   inflating: /content/data/verification_data/00064682.jpg
#   inflating: /content/data/verification_data/00064683.jpg
#   inflating: /content/data/verification_data/00064684.jpg
#   inflating: /content/data/verification_data/00064685.jpg
#   inflating: /content/data/verification_data/00064686.jpg
#   inflating: /content/data/verification_data/00064687.jpg
#   inflating: /content/data/verification_data/00064688.jpg
#   inflating: /content/data/verification_data/00064689.jpg
#   inflating: /content/data/verification_data/00064690.jpg
#   inflating: /content/data/verification_data/00064691.jpg
#   inflating: /content/data/verification_data/00064692.jpg
#   inflating: /content/data/verification_data/00064693.jpg
#   inflating: /content/data/verification_data/00064694.jpg
#   inflating: /content/data/verification_data/00064695.jpg
#   inflating: /content/data/verification_data/00064696.jpg
#   inflating: /content/data/verification_data/00064697.jpg
#   inflating: /content/data/verification_data/00064698.jpg
#   inflating: /content/data/verification_data/00064699.jpg
#   inflating: /content/data/verification_data/00064700.jpg
#   inflating: /content/data/verification_data/00064701.jpg
#   inflating: /content/data/verification_data/00064702.jpg
#   inflating: /content/data/verification_data/00064703.jpg
#   inflating: /content/data/verification_data/00064704.jpg
#   inflating: /content/data/verification_data/00064705.jpg
#   inflating: /content/data/verification_data/00064706.jpg
#   inflating: /content/data/verification_data/00064707.jpg
#   inflating: /content/data/verification_data/00064708.jpg
#   inflating: /content/data/verification_data/00064709.jpg
#   inflating: /content/data/verification_data/00064710.jpg
#   inflating: /content/data/verification_data/00064711.jpg
#   inflating: /content/data/verification_data/00064712.jpg
#   inflating: /content/data/verification_data/00064713.jpg
#   inflating: /content/data/verification_data/00064714.jpg
#   inflating: /content/data/verification_data/00064715.jpg
#   inflating: /content/data/verification_data/00064716.jpg
#   inflating: /content/data/verification_data/00064717.jpg
#   inflating: /content/data/verification_data/00064718.jpg
#   inflating: /content/data/verification_data/00064719.jpg
#   inflating: /content/data/verification_data/00064720.jpg
#   inflating: /content/data/verification_data/00064721.jpg
#   inflating: /content/data/verification_data/00064722.jpg
#   inflating: /content/data/verification_data/00064723.jpg
#   inflating: /content/data/verification_data/00064724.jpg
#   inflating: /content/data/verification_data/00064725.jpg
#   inflating: /content/data/verification_data/00064726.jpg
#   inflating: /content/data/verification_data/00064727.jpg
#   inflating: /content/data/verification_data/00064728.jpg
#   inflating: /content/data/verification_data/00064729.jpg
#   inflating: /content/data/verification_data/00064730.jpg
#   inflating: /content/data/verification_data/00064731.jpg
#   inflating: /content/data/verification_data/00064732.jpg
#   inflating: /content/data/verification_data/00064733.jpg
#   inflating: /content/data/verification_data/00064734.jpg
#   inflating: /content/data/verification_data/00064735.jpg
#   inflating: /content/data/verification_data/00064736.jpg
#   inflating: /content/data/verification_data/00064737.jpg
#   inflating: /content/data/verification_data/00064738.jpg
#   inflating: /content/data/verification_data/00064739.jpg
#   inflating: /content/data/verification_data/00064740.jpg
#   inflating: /content/data/verification_data/00064741.jpg
#   inflating: /content/data/verification_data/00064742.jpg
#   inflating: /content/data/verification_data/00064743.jpg
#   inflating: /content/data/verification_data/00064744.jpg
#   inflating: /content/data/verification_data/00064745.jpg
#   inflating: /content/data/verification_data/00064746.jpg
#   inflating: /content/data/verification_data/00064747.jpg
#   inflating: /content/data/verification_data/00064748.jpg
#   inflating: /content/data/verification_data/00064749.jpg
#   inflating: /content/data/verification_data/00064750.jpg
#   inflating: /content/data/verification_data/00064751.jpg
#   inflating: /content/data/verification_data/00064752.jpg
#   inflating: /content/data/verification_data/00064753.jpg
#   inflating: /content/data/verification_data/00064754.jpg
#   inflating: /content/data/verification_data/00064755.jpg
#   inflating: /content/data/verification_data/00064756.jpg
#   inflating: /content/data/verification_data/00064757.jpg
#   inflating: /content/data/verification_data/00064758.jpg
#   inflating: /content/data/verification_data/00064759.jpg
#   inflating: /content/data/verification_data/00064760.jpg
#   inflating: /content/data/verification_data/00064761.jpg
#   inflating: /content/data/verification_data/00064762.jpg
#   inflating: /content/data/verification_data/00064763.jpg
#   inflating: /content/data/verification_data/00064764.jpg
#   inflating: /content/data/verification_data/00064765.jpg
#   inflating: /content/data/verification_data/00064766.jpg
#   inflating: /content/data/verification_data/00064767.jpg
#   inflating: /content/data/verification_data/00064768.jpg
#   inflating: /content/data/verification_data/00064769.jpg
#   inflating: /content/data/verification_data/00064770.jpg
#   inflating: /content/data/verification_data/00064771.jpg
#   inflating: /content/data/verification_data/00064772.jpg
#   inflating: /content/data/verification_data/00064773.jpg
#   inflating: /content/data/verification_data/00064774.jpg
#   inflating: /content/data/verification_data/00064775.jpg
#   inflating: /content/data/verification_data/00064776.jpg
#   inflating: /content/data/verification_data/00064777.jpg
#   inflating: /content/data/verification_data/00064778.jpg
#   inflating: /content/data/verification_data/00064779.jpg
#   inflating: /content/data/verification_data/00064780.jpg
#   inflating: /content/data/verification_data/00064781.jpg
#   inflating: /content/data/verification_data/00064782.jpg
#   inflating: /content/data/verification_data/00064783.jpg
#   inflating: /content/data/verification_data/00064784.jpg
#   inflating: /content/data/verification_data/00064785.jpg
#   inflating: /content/data/verification_data/00064786.jpg
#   inflating: /content/data/verification_data/00064787.jpg
#   inflating: /content/data/verification_data/00064788.jpg
#   inflating: /content/data/verification_data/00064789.jpg
#   inflating: /content/data/verification_data/00064790.jpg
#   inflating: /content/data/verification_data/00064791.jpg
#   inflating: /content/data/verification_data/00064792.jpg
#   inflating: /content/data/verification_data/00064793.jpg
#   inflating: /content/data/verification_data/00064794.jpg
#   inflating: /content/data/verification_data/00064795.jpg
#   inflating: /content/data/verification_data/00064796.jpg
#   inflating: /content/data/verification_data/00064797.jpg
#   inflating: /content/data/verification_data/00064798.jpg
#   inflating: /content/data/verification_data/00064799.jpg
#   inflating: /content/data/verification_data/00064800.jpg
#   inflating: /content/data/verification_data/00064801.jpg
#   inflating: /content/data/verification_data/00064802.jpg
#   inflating: /content/data/verification_data/00064803.jpg
#   inflating: /content/data/verification_data/00064804.jpg
#   inflating: /content/data/verification_data/00064805.jpg
#   inflating: /content/data/verification_data/00064806.jpg
#   inflating: /content/data/verification_data/00064807.jpg
#   inflating: /content/data/verification_data/00064808.jpg
#   inflating: /content/data/verification_data/00064809.jpg
#   inflating: /content/data/verification_data/00064810.jpg
#   inflating: /content/data/verification_data/00064811.jpg
#   inflating: /content/data/verification_data/00064812.jpg
#   inflating: /content/data/verification_data/00064813.jpg
#   inflating: /content/data/verification_data/00064814.jpg
#   inflating: /content/data/verification_data/00064815.jpg
#   inflating: /content/data/verification_data/00064816.jpg
#   inflating: /content/data/verification_data/00064817.jpg
#   inflating: /content/data/verification_data/00064818.jpg
#   inflating: /content/data/verification_data/00064819.jpg
#   inflating: /content/data/verification_data/00064820.jpg
#   inflating: /content/data/verification_data/00064821.jpg
#   inflating: /content/data/verification_data/00064822.jpg
#   inflating: /content/data/verification_data/00064823.jpg
#   inflating: /content/data/verification_data/00064824.jpg
#   inflating: /content/data/verification_data/00064825.jpg
#   inflating: /content/data/verification_data/00064826.jpg
#   inflating: /content/data/verification_data/00064827.jpg
#   inflating: /content/data/verification_data/00064828.jpg
#   inflating: /content/data/verification_data/00064829.jpg
#   inflating: /content/data/verification_data/00064830.jpg
#   inflating: /content/data/verification_data/00064831.jpg
#   inflating: /content/data/verification_data/00064832.jpg
#   inflating: /content/data/verification_data/00064833.jpg
#   inflating: /content/data/verification_data/00064834.jpg
#   inflating: /content/data/verification_data/00064835.jpg
#   inflating: /content/data/verification_data/00064836.jpg
#   inflating: /content/data/verification_data/00064837.jpg
#   inflating: /content/data/verification_data/00064838.jpg
#   inflating: /content/data/verification_data/00064839.jpg
#   inflating: /content/data/verification_data/00064840.jpg
#   inflating: /content/data/verification_data/00064841.jpg
#   inflating: /content/data/verification_data/00064842.jpg
#   inflating: /content/data/verification_data/00064843.jpg
#   inflating: /content/data/verification_data/00064844.jpg
#   inflating: /content/data/verification_data/00064845.jpg
#   inflating: /content/data/verification_data/00064846.jpg
#   inflating: /content/data/verification_data/00064847.jpg
#   inflating: /content/data/verification_data/00064848.jpg
#   inflating: /content/data/verification_data/00064849.jpg
#   inflating: /content/data/verification_data/00064850.jpg
#   inflating: /content/data/verification_data/00064851.jpg
#   inflating: /content/data/verification_data/00064852.jpg
#   inflating: /content/data/verification_data/00064853.jpg
#   inflating: /content/data/verification_data/00064854.jpg
#   inflating: /content/data/verification_data/00064855.jpg
#   inflating: /content/data/verification_data/00064856.jpg
#   inflating: /content/data/verification_data/00064857.jpg
#   inflating: /content/data/verification_data/00064858.jpg
#   inflating: /content/data/verification_data/00064859.jpg
#   inflating: /content/data/verification_data/00064860.jpg
#   inflating: /content/data/verification_data/00064861.jpg
#   inflating: /content/data/verification_data/00064862.jpg
#   inflating: /content/data/verification_data/00064863.jpg
#   inflating: /content/data/verification_data/00064864.jpg
#   inflating: /content/data/verification_data/00064865.jpg
#   inflating: /content/data/verification_data/00064866.jpg
#   inflating: /content/data/verification_data/00064867.jpg
#   inflating: /content/data/verification_data/00064868.jpg
#   inflating: /content/data/verification_data/00064869.jpg
#   inflating: /content/data/verification_data/00064870.jpg
#   inflating: /content/data/verification_data/00064871.jpg
#   inflating: /content/data/verification_data/00064872.jpg
#   inflating: /content/data/verification_data/00064873.jpg
#   inflating: /content/data/verification_data/00064874.jpg
#   inflating: /content/data/verification_data/00064875.jpg
#   inflating: /content/data/verification_data/00064876.jpg
#   inflating: /content/data/verification_data/00064877.jpg
#   inflating: /content/data/verification_data/00064878.jpg
#   inflating: /content/data/verification_data/00064879.jpg
#   inflating: /content/data/verification_data/00064880.jpg
#   inflating: /content/data/verification_data/00064881.jpg
#   inflating: /content/data/verification_data/00064882.jpg
#   inflating: /content/data/verification_data/00064883.jpg
#   inflating: /content/data/verification_data/00064884.jpg
#   inflating: /content/data/verification_data/00064885.jpg
#   inflating: /content/data/verification_data/00064886.jpg
#   inflating: /content/data/verification_data/00064887.jpg
#   inflating: /content/data/verification_data/00064888.jpg
#   inflating: /content/data/verification_data/00064889.jpg
#   inflating: /content/data/verification_data/00064890.jpg
#   inflating: /content/data/verification_data/00064891.jpg
#   inflating: /content/data/verification_data/00064892.jpg
#   inflating: /content/data/verification_data/00064893.jpg
#   inflating: /content/data/verification_data/00064894.jpg
#   inflating: /content/data/verification_data/00064895.jpg
#   inflating: /content/data/verification_data/00064896.jpg
#   inflating: /content/data/verification_data/00064897.jpg
# ...
#   inflating: /content/data/verification_data/00068833.jpg
#   inflating: /content/data/verification_data/00068834.jpg
#   inflating: /content/data/verification_data/00068835.jpg
#   inflating: /content/data/verification_data/00068836.jpg
#   inflating: /content/data/verification_data/00068837.jpg
#   inflating: /content/data/verification_data/00068838.jpg
#   inflating: /content/data/verification_data/00068839.jpg
#   inflating: /content/data/verification_data/00068840.jpg
#   inflating: /content/data/verification_data/00068841.jpg
#   inflating: /content/data/verification_data/00068842.jpg
#   inflating: /content/data/verification_data/00068843.jpg
#   inflating: /content/data/verification_data/00068844.jpg
#   inflating: /content/data/verification_data/00068845.jpg
#   inflating: /content/data/verification_data/00068846.jpg
#   inflating: /content/data/verification_data/00068847.jpg
#   inflating: /content/data/verification_data/00068848.jpg
#   inflating: /content/data/verification_data/00068849.jpg
#   inflating: /content/data/verification_data/00068850.jpg
#   inflating: /content/data/verification_data/00068851.jpg
#   inflating: /content/data/verification_data/00068852.jpg
#   inflating: /content/data/verification_data/00068853.jpg
#   inflating: /content/data/verification_data/00068854.jpg
#   inflating: /content/data/verification_data/00068855.jpg
#   inflating: /content/data/verification_data/00068856.jpg
#   inflating: /content/data/verification_data/00068857.jpg
#   inflating: /content/data/verification_data/00068858.jpg
#   inflating: /content/data/verification_data/00068859.jpg
#   inflating: /content/data/verification_data/00068860.jpg
#   inflating: /content/data/verification_data/00068861.jpg
#   inflating: /content/data/verification_data/00068862.jpg
#   inflating: /content/data/verification_data/00068863.jpg
#   inflating: /content/data/verification_data/00068864.jpg
#   inflating: /content/data/verification_data/00068865.jpg
#   inflating: /content/data/verification_data/00068866.jpg
#   inflating: /content/data/verification_data/00068867.jpg
#   inflating: /content/data/verification_data/00068868.jpg
#   inflating: /content/data/verification_data/00068869.jpg
#   inflating: /content/data/verification_data/00068870.jpg
#   inflating: /content/data/verification_data/00068871.jpg
#   inflating: /content/data/verification_data/00068872.jpg
#   inflating: /content/data/verification_data/00068873.jpg
#   inflating: /content/data/verification_data/00068874.jpg
#   inflating: /content/data/verification_data/00068875.jpg
#   inflating: /content/data/verification_data/00068876.jpg
#   inflating: /content/data/verification_data/00068877.jpg
#   inflating: /content/data/verification_data/00068878.jpg
#   inflating: /content/data/verification_data/00068879.jpg
#   inflating: /content/data/verification_data/00068880.jpg
#   inflating: /content/data/verification_data/00068881.jpg
#   inflating: /content/data/verification_data/00068882.jpg
#   inflating: /content/data/verification_data/00068883.jpg
#   inflating: /content/data/verification_data/00068884.jpg
#   inflating: /content/data/verification_data/00068885.jpg
#   inflating: /content/data/verification_data/00068886.jpg
#   inflating: /content/data/verification_data/00068887.jpg
#   inflating: /content/data/verification_data/00068888.jpg
#   inflating: /content/data/verification_data/00068889.jpg
#   inflating: /content/data/verification_data/00068890.jpg
#   inflating: /content/data/verification_data/00068891.jpg
#   inflating: /content/data/verification_data/00068892.jpg
#   inflating: /content/data/verification_data/00068893.jpg
#   inflating: /content/data/verification_data/00068894.jpg
#   inflating: /content/data/verification_data/00068895.jpg
#   inflating: /content/data/verification_data/00068896.jpg
#   inflating: /content/data/verification_data/00068897.jpg
#   inflating: /content/data/verification_data/00068898.jpg
#   inflating: /content/data/verification_data/00068899.jpg
#   inflating: /content/data/verification_data/00068900.jpg
#   inflating: /content/data/verification_data/00068901.jpg
#   inflating: /content/data/verification_data/00068902.jpg
#   inflating: /content/data/verification_data/00068903.jpg
#   inflating: /content/data/verification_data/00068904.jpg
#   inflating: /content/data/verification_data/00068905.jpg
#   inflating: /content/data/verification_data/00068906.jpg
#   inflating: /content/data/verification_data/00068907.jpg
#   inflating: /content/data/verification_data/00068908.jpg
#   inflating: /content/data/verification_data/00068909.jpg
#   inflating: /content/data/verification_data/00068910.jpg
#   inflating: /content/data/verification_data/00068911.jpg
#   inflating: /content/data/verification_data/00068912.jpg
#   inflating: /content/data/verification_data/00068913.jpg
#   inflating: /content/data/verification_data/00068914.jpg
#   inflating: /content/data/verification_data/00068915.jpg
#   inflating: /content/data/verification_data/00068916.jpg
#   inflating: /content/data/verification_data/00068917.jpg
#   inflating: /content/data/verification_data/00068918.jpg
#   inflating: /content/data/verification_data/00068919.jpg
#   inflating: /content/data/verification_data/00068920.jpg
#   inflating: /content/data/verification_data/00068921.jpg
#   inflating: /content/data/verification_data/00068922.jpg
#   inflating: /content/data/verification_data/00068923.jpg
#   inflating: /content/data/verification_data/00068924.jpg
#   inflating: /content/data/verification_data/00068925.jpg
#   inflating: /content/data/verification_data/00068926.jpg
#   inflating: /content/data/verification_data/00068927.jpg
#   inflating: /content/data/verification_data/00068928.jpg
#   inflating: /content/data/verification_data/00068929.jpg
#   inflating: /content/data/verification_data/00068930.jpg
#   inflating: /content/data/verification_data/00068931.jpg
#   inflating: /content/data/verification_data/00068932.jpg
#   inflating: /content/data/verification_data/00068933.jpg
#   inflating: /content/data/verification_data/00068934.jpg
#   inflating: /content/data/verification_data/00068935.jpg
#   inflating: /content/data/verification_data/00068936.jpg
#   inflating: /content/data/verification_data/00068937.jpg
#   inflating: /content/data/verification_data/00068938.jpg
#   inflating: /content/data/verification_data/00068939.jpg
#   inflating: /content/data/verification_data/00068940.jpg
#   inflating: /content/data/verification_data/00068941.jpg
#   inflating: /content/data/verification_data/00068942.jpg
#   inflating: /content/data/verification_data/00068943.jpg
#   inflating: /content/data/verification_data/00068944.jpg
#   inflating: /content/data/verification_data/00068945.jpg
#   inflating: /content/data/verification_data/00068946.jpg
#   inflating: /content/data/verification_data/00068947.jpg
#   inflating: /content/data/verification_data/00068948.jpg
#   inflating: /content/data/verification_data/00068949.jpg
#   inflating: /content/data/verification_data/00068950.jpg
#   inflating: /content/data/verification_data/00068951.jpg
#   inflating: /content/data/verification_data/00068952.jpg
#   inflating: /content/data/verification_data/00068953.jpg
#   inflating: /content/data/verification_data/00068954.jpg
#   inflating: /content/data/verification_data/00068955.jpg
#   inflating: /content/data/verification_data/00068956.jpg
#   inflating: /content/data/verification_data/00068957.jpg
#   inflating: /content/data/verification_data/00068958.jpg
#   inflating: /content/data/verification_data/00068959.jpg
#   inflating: /content/data/verification_data/00068960.jpg
#   inflating: /content/data/verification_data/00068961.jpg
#   inflating: /content/data/verification_data/00068962.jpg
#   inflating: /content/data/verification_data/00068963.jpg
#   inflating: /content/data/verification_data/00068964.jpg
#   inflating: /content/data/verification_data/00068965.jpg
#   inflating: /content/data/verification_data/00068966.jpg
#   inflating: /content/data/verification_data/00068967.jpg
#   inflating: /content/data/verification_data/00068968.jpg
#   inflating: /content/data/verification_data/00068969.jpg
#   inflating: /content/data/verification_data/00068970.jpg
#   inflating: /content/data/verification_data/00068971.jpg
#   inflating: /content/data/verification_data/00068972.jpg
#   inflating: /content/data/verification_data/00068973.jpg
#   inflating: /content/data/verification_data/00068974.jpg
#   inflating: /content/data/verification_data/00068975.jpg
#   inflating: /content/data/verification_data/00068976.jpg
#   inflating: /content/data/verification_data/00068977.jpg
#   inflating: /content/data/verification_data/00068978.jpg
#   inflating: /content/data/verification_data/00068979.jpg
#   inflating: /content/data/verification_data/00068980.jpg
#   inflating: /content/data/verification_data/00068981.jpg
#   inflating: /content/data/verification_data/00068982.jpg
#   inflating: /content/data/verification_data/00068983.jpg
#   inflating: /content/data/verification_data/00068984.jpg
#   inflating: /content/data/verification_data/00068985.jpg
#   inflating: /content/data/verification_data/00068986.jpg
#   inflating: /content/data/verification_data/00068987.jpg
#   inflating: /content/data/verification_data/00068988.jpg
#   inflating: /content/data/verification_data/00068989.jpg
#   inflating: /content/data/verification_data/00068990.jpg
#   inflating: /content/data/verification_data/00068991.jpg
#   inflating: /content/data/verification_data/00068992.jpg
#   inflating: /content/data/verification_data/00068993.jpg
#   inflating: /content/data/verification_data/00068994.jpg
#   inflating: /content/data/verification_data/00068995.jpg
#   inflating: /content/data/verification_data/00068996.jpg
#   inflating: /content/data/verification_data/00068997.jpg
#   inflating: /content/data/verification_data/00068998.jpg
#   inflating: /content/data/verification_data/00068999.jpg
#   inflating: /content/data/verification_data/00069000.jpg
#   inflating: /content/data/verification_data/00069001.jpg
#   inflating: /content/data/verification_data/00069002.jpg
#   inflating: /content/data/verification_data/00069003.jpg
#   inflating: /content/data/verification_data/00069004.jpg
#   inflating: /content/data/verification_data/00069005.jpg
#   inflating: /content/data/verification_data/00069006.jpg
#   inflating: /content/data/verification_data/00069007.jpg
#   inflating: /content/data/verification_data/00069008.jpg
#   inflating: /content/data/verification_data/00069009.jpg
#   inflating: /content/data/verification_data/00069010.jpg
#   inflating: /content/data/verification_data/00069011.jpg
#   inflating: /content/data/verification_data/00069012.jpg
#   inflating: /content/data/verification_data/00069013.jpg
#   inflating: /content/data/verification_data/00069014.jpg
#   inflating: /content/data/verification_data/00069015.jpg
#   inflating: /content/data/verification_data/00069016.jpg
#   inflating: /content/data/verification_data/00069017.jpg
#   inflating: /content/data/verification_data/00069018.jpg
#   inflating: /content/data/verification_data/00069019.jpg
#   inflating: /content/data/verification_data/00069020.jpg
#   inflating: /content/data/verification_data/00069021.jpg
#   inflating: /content/data/verification_data/00069022.jpg
#   inflating: /content/data/verification_data/00069023.jpg
#   inflating: /content/data/verification_data/00069024.jpg
#   inflating: /content/data/verification_data/00069025.jpg
#   inflating: /content/data/verification_data/00069026.jpg
#   inflating: /content/data/verification_data/00069027.jpg
#   inflating: /content/data/verification_data/00069028.jpg
#   inflating: /content/data/verification_data/00069029.jpg
#   inflating: /content/data/verification_data/00069030.jpg
#   inflating: /content/data/verification_data/00069031.jpg
#   inflating: /content/data/verification_data/00069032.jpg
#   inflating: /content/data/verification_data/00069033.jpg
#   inflating: /content/data/verification_data/00069034.jpg
#   inflating: /content/data/verification_data/00069035.jpg
#   inflating: /content/data/verification_data/00069036.jpg
#   inflating: /content/data/verification_data/00069037.jpg
#   inflating: /content/data/verification_data/00069038.jpg
#   inflating: /content/data/verification_data/00069039.jpg
#   inflating: /content/data/verification_data/00069040.jpg
#   inflating: /content/data/verification_data/00069041.jpg
#   inflating: /content/data/verification_data/00069042.jpg
#   inflating: /content/data/verification_data/00069043.jpg
#   inflating: /content/data/verification_data/00069044.jpg
#   inflating: /content/data/verification_data/00069045.jpg
#   inflating: /content/data/verification_data/00069046.jpg
#   inflating: /content/data/verification_data/00069047.jpg
#   inflating: /content/data/verification_data/00069048.jpg
#   inflating: /content/data/verification_data/00069049.jpg
#   inflating: /content/data/verification_data/00069050.jpg
#   inflating: /content/data/verification_data/00069051.jpg
#   inflating: /content/data/verification_data/00069052.jpg
#   inflating: /content/data/verification_data/00069053.jpg
#   inflating: /content/data/verification_data/00069054.jpg
#   inflating: /content/data/verification_data/00069055.jpg
#   inflating: /content/data/verification_data/00069056.jpg
#   inflating: /content/data/verification_data/00069057.jpg
#   inflating: /content/data/verification_data/00069058.jpg
#   inflating: /content/data/verification_data/00069059.jpg
#   inflating: /content/data/verification_data/00069060.jpg
#   inflating: /content/data/verification_data/00069061.jpg
#   inflating: /content/data/verification_data/00069062.jpg
#   inflating: /content/data/verification_data/00069063.jpg
#   inflating: /content/data/verification_data/00069064.jpg
#   inflating: /content/data/verification_data/00069065.jpg
#   inflating: /content/data/verification_data/00069066.jpg
#   inflating: /content/data/verification_data/00069067.jpg
#   inflating: /content/data/verification_data/00069068.jpg
#   inflating: /content/data/verification_data/00069069.jpg
#   inflating: /content/data/verification_data/00069070.jpg
#   inflating: /content/data/verification_data/00069071.jpg
#   inflating: /content/data/verification_data/00069072.jpg
#   inflating: /content/data/verification_data/00069073.jpg
#   inflating: /content/data/verification_data/00069074.jpg
#   inflating: /content/data/verification_data/00069075.jpg
#   inflating: /content/data/verification_data/00069076.jpg
#   inflating: /content/data/verification_data/00069077.jpg
#   inflating: /content/data/verification_data/00069078.jpg
#   inflating: /content/data/verification_data/00069079.jpg
#   inflating: /content/data/verification_data/00069080.jpg
#   inflating: /content/data/verification_data/00069081.jpg
#   inflating: /content/data/verification_data/00069082.jpg
#   inflating: /content/data/verification_data/00069083.jpg
#   inflating: /content/data/verification_data/00069084.jpg
#   inflating: /content/data/verification_data/00069085.jpg
#   inflating: /content/data/verification_data/00069086.jpg
#   inflating: /content/data/verification_data/00069087.jpg
#   inflating: /content/data/verification_data/00069088.jpg
#   inflating: /content/data/verification_data/00069089.jpg
#   inflating: /content/data/verification_data/00069090.jpg
#   inflating: /content/data/verification_data/00069091.jpg
#   inflating: /content/data/verification_data/00069092.jpg
#   inflating: /content/data/verification_data/00069093.jpg
#   inflating: /content/data/verification_data/00069094.jpg
#   inflating: /content/data/verification_data/00069095.jpg
#   inflating: /content/data/verification_data/00069096.jpg
#   inflating: /content/data/verification_pairs_test.txt
#   inflating: /content/data/verification_pairs_val.txt

# %%
# !ls "/content/data/classification_data/train_data/n003212"
# Out:
# 0013_01.jpg  0083_03.jpg  0151_01.jpg  0226_01.jpg  0285_01.jpg  0333_01.jpg
# 0014_01.jpg  0086_01.jpg  0151_02.jpg  0231_01.jpg  0287_01.jpg  0337_01.jpg
# 0024_01.jpg  0087_01.jpg  0159_04.jpg  0232_01.jpg  0290_02.jpg  0345_01.jpg
# 0029_02.jpg  0099_01.jpg  0160_01.jpg  0236_01.jpg  0294_01.jpg  0346_01.jpg
# 0033_01.jpg  0109_01.jpg  0163_01.jpg  0239_01.jpg  0296_02.jpg  0348_01.jpg
# 0034_01.jpg  0110_01.jpg  0164_01.jpg  0245_01.jpg  0304_01.jpg  0351_01.jpg
# 0042_01.jpg  0111_01.jpg  0172_01.jpg  0250_01.jpg  0305_01.jpg  0364_01.jpg
# 0050_01.jpg  0120_01.jpg  0187_01.jpg  0260_03.jpg  0311_01.jpg  0370_01.jpg
# 0053_02.jpg  0121_02.jpg  0191_02.jpg  0263_01.jpg  0314_01.jpg  0386_01.jpg
# 0061_01.jpg  0122_01.jpg  0193_02.jpg  0266_01.jpg  0315_01.jpg  0389_01.jpg
# 0062_02.jpg  0124_01.jpg  0202_01.jpg  0271_01.jpg  0317_01.jpg  0390_01.jpg
# 0070_01.jpg  0125_01.jpg  0207_02.jpg  0277_01.jpg  0322_01.jpg  0406_02.jpg
# 0075_01.jpg  0126_01.jpg  0208_02.jpg  0281_01.jpg  0324_03.jpg  0411_01.jpg
# 0076_01.jpg  0129_01.jpg  0222_01.jpg  0282_01.jpg  0331_02.jpg

# %%
import os
TRAIN_DIR = "/content/data/classification_data/train_data/"
data_manifest = {}
for person_id in os.listdir(TRAIN_DIR):
    person_path = os.path.join(TRAIN_DIR, person_id)
    if os.path.isdir(person_path):
        images = [os.path.join(person_path, f) for f in os.listdir(person_path)]
        # You need at least 2 images to make an (Anchor, Positive) pair
        if len(images) > 1:
            data_manifest[person_id] = images

# This list will be used to pick random people
person_ids_list = list(data_manifest.keys())

# %%
# Display the first 5 entries of data_manifest to check its structure
from itertools import islice

def display_dict_head(dictionary, num_entries=5):
    print(dict(islice(dictionary.items(), num_entries)))

display_dict_head(data_manifest)
# Out:
# {'n000291': ['/content/data/classification_data/train_data/n000291/0321_01.jpg', '/content/data/classification_data/train_data/n000291/0122_03.jpg', '/content/data/classification_data/train_data/n000291/0172_01.jpg', '/content/data/classification_data/train_data/n000291/0046_01.jpg', '/content/data/classification_data/train_data/n000291/0343_01.jpg', '/content/data/classification_data/train_data/n000291/0030_03.jpg', '/content/data/classification_data/train_data/n000291/0037_01.jpg', '/content/data/classification_data/train_data/n000291/0026_02.jpg', '/content/data/classification_data/train_data/n000291/0112_01.jpg', '/content/data/classification_data/train_data/n000291/0079_02.jpg', '/content/data/classification_data/train_data/n000291/0341_01.jpg', '/content/data/classification_data/train_data/n000291/0054_01.jpg', '/content/data/classification_data/train_data/n000291/0145_04.jpg', '/content/data/classification_data/train_data/n000291/0191_02.jpg', '/content/data/classification_data/train_data/n000291/0344_02.jpg', '/content/data/classification_data/train_data/n000291/0356_01.jpg', '/content/data/classification_data/train_data/n000291/0128_02.jpg', '/content/data/classification_data/train_data/n000291/0113_01.jpg', '/content/data/classification_data/train_data/n000291/0195_01.jpg', '/content/data/classification_data/train_data/n000291/0021_02.jpg', '/content/data/classification_data/train_data/n000291/0063_01.jpg', '/content/data/classification_data/train_data/n000291/0273_01.jpg', '/content/data/classification_data/train_data/n000291/0181_02.jpg', '/content/data/classification_data/train_data/n000291/0379_01.jpg', '/content/data/classification_data/train_data/n000291/0205_02.jpg', '/content/data/classification_data/train_data/n000291/0147_01.jpg', '/content/data/classification_data/train_data/n000291/0076_03.jpg', '/content/data/classification_data/train_data/n000291/0266_01.jpg', '/content/data/classification_data/train_data/n000291/0098_01.jpg', '/content/data/classification_data/train_data/n000291/0201_02.jpg', '/content/data/classification_data/train_data/n000291/0116_01.jpg', '/content/data/classification_data/train_data/n000291/0293_01.jpg', '/content/data/classification_data/train_data/n000291/0300_02.jpg', '/content/data/classification_data/train_data/n000291/0080_01.jpg', '/content/data/classification_data/train_data/n000291/0228_02.jpg', '/content/data/classification_data/train_data/n000291/0003_01.jpg', '/content/data/classification_data/train_data/n000291/0131_02.jpg', '/content/data/classification_data/train_data/n000291/0199_01.jpg', '/content/data/classification_data/train_data/n000291/0248_01.jpg', '/content/data/classification_data/train_data/n000291/0144_02.jpg', '/content/data/classification_data/train_data/n000291/0227_01.jpg', '/content/data/classification_data/train_data/n000291/0019_03.jpg', '/content/data/classification_data/train_data/n000291/0221_01.jpg', '/content/data/classification_data/train_data/n000291/0313_02.jpg', '/content/data/classification_data/train_data/n000291/0156_01.jpg', '/content/data/classification_data/train_data/n000291/0130_01.jpg', '/content/data/classification_data/train_data/n000291/0202_02.jpg', '/content/data/classification_data/train_data/n000291/0014_01.jpg', '/content/data/classification_data/train_data/n000291/0125_01.jpg', '/content/data/classification_data/train_data/n000291/0068_01.jpg', '/content/data/classification_data/train_data/n000291/0134_01.jpg', '/content/data/classification_data/train_data/n000291/0155_01.jpg', '/content/data/classification_data/train_data/n000291/0148_01.jpg', '/content/data/classification_data/train_data/n000291/0044_01.jpg', '/content/data/classification_data/train_data/n000291/0236_01.jpg', '/content/data/classification_data/train_data/n000291/0100_04.jpg', '/content/data/classification_data/train_data/n000291/0115_01.jpg', '/content/data/classification_data/train_data/n000291/0231_01.jpg', '/content/data/classification_data/train_da ...

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
import os
import random
import numpy as np
from glob import glob

from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input as resnet50_preprocess
from tensorflow.keras.layers import (
    Input, Dense, GlobalAveragePooling2D, Lambda, BatchNormalization, Activation
)
from tensorflow.keras.models import Model
from tensorflow.keras.utils import image_dataset_from_directory

# --- Define project constants ---
IMAGE_SIZE = (224, 224) # Use 224x224 for ResNet50
BATCH_SIZE = 32
EMBEDDING_DIM = 128
MARGIN = 0.5
ROOT_DIR = "/content/data/" # Use a root variable

# Update paths to use the root dir
TRAIN_DIR = os.path.join(ROOT_DIR, "classification_data/train_data")
VAL_DIR = os.path.join(ROOT_DIR, "classification_data/val_data")
PAIRS_FILE = os.path.join(ROOT_DIR, "verification_pairs_val.txt")
PAIRS_BASE_DIR = ROOT_DIR # The pairs file paths are relative to this

print(f"TensorFlow version: {tf.__version__}")
print(f"GPU is {'available' if tf.config.list_physical_devices('GPU') else 'NOT AVAILABLE'}")

# %matplotlib inline
# Out:
# TensorFlow version: 2.19.0
# GPU is available

# %%
def load_and_prep(image_path):
    """Loads, augments, and preprocesses a single image file path."""
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)

    # --- Data Augmentation ---
    # Resize to slightly larger, then random crop.
    # This simulates "different view points" by forcing the model
    # to find the face even if it's not centered.
    image = tf.image.resize(image, (256, 256))
    image = tf.image.random_crop(image, (IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_brightness(image, max_delta=0.2)

    # --- Normalization (CRITICAL) ---
    image = resnet50_preprocess(image)
    return image

def triplet_generator():
    """A Python generator that yields file paths for (A, P, N) triplets."""
    while True:
        # 1. Pick Anchor and Positive
        anchor_id = random.choice(person_ids_list)
        anchor_path, positive_path = random.sample(data_manifest[anchor_id], 2)

        # 2. Pick Negative
        negative_id = random.choice(person_ids_list)
        while negative_id == anchor_id:
            negative_id = random.choice(person_ids_list)
        negative_path = random.choice(data_manifest[negative_id])

        yield (anchor_path, positive_path, negative_path)

# Define a separate generator for validation data
def val_triplet_generator():
    """A Python generator that yields file paths for (A, P, N) triplets for validation."""
    while True:
        # 1. Pick Anchor and Positive from validation data
        anchor_id = random.choice(val_person_ids_list)
        anchor_path, positive_path = random.sample(val_manifest[anchor_id], 2)

        # 2. Pick Negative from validation data
        negative_id = random.choice(val_person_ids_list)
        while negative_id == anchor_id:
            negative_id = random.choice(val_person_ids_list)
        negative_path = random.choice(val_manifest[negative_id])

        yield (anchor_path, positive_path, negative_path)


def load_triplet_images(anchor_path, positive_path, negative_path):
    """The main mapping function for tf.data"""
    return (
        load_and_prep(anchor_path),
        load_and_prep(positive_path),
        load_and_prep(negative_path)
    ), 0 # '0' is a dummy label, our loss function ignores it

# --- Create the final, optimized tf.data.Dataset ---
triplets_dataset = tf.data.Dataset.from_generator(
    triplet_generator,
    output_signature=(
        (tf.TensorSpec(shape=(), dtype=tf.string),
         tf.TensorSpec(shape=(), dtype=tf.string),
         tf.TensorSpec(shape=(), dtype=tf.string))
    )
)

# This is where the magic happens. We run everything in parallel.
triplets_dataset = triplets_dataset.map(
    load_triplet_images,
    num_parallel_calls=tf.data.AUTOTUNE
)
triplets_dataset = triplets_dataset.batch(BATCH_SIZE)
triplets_dataset = triplets_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# We do the same for a validation set
# (Assuming val_data has a similar structure)
# NOTE: You MUST create a separate validation manifest
print("Building validation manifest...")
val_manifest = {}
val_person_ids_list = []
for person_id in os.listdir(VAL_DIR):
    person_path = os.path.join(VAL_DIR, person_id)
    if os.path.isdir(person_path):
        images = glob(os.path.join(person_path, "*.jpg")) + \
                 glob(os.path.join(person_path, "*.png"))
        if len(images) > 1:
            val_manifest[person_id] = images
            val_person_ids_list.append(person_id)

# Use the separate generator for validation data
val_triplets_dataset = tf.data.Dataset.from_generator(
    val_triplet_generator,
    output_signature=(
        (tf.TensorSpec(shape=(), dtype=tf.string),
         tf.TensorSpec(shape=(), dtype=tf.string),
         tf.TensorSpec(shape=(), dtype=tf.string))
    )
).map(load_triplet_images, num_parallel_calls=tf.data.AUTOTUNE) \
 .batch(BATCH_SIZE).prefetch(buffer_size=tf.data.AUTOTUNE)

print("Metric Learning Data Pipelines: READY")
# Out:
# Building validation manifest...
# Metric Learning Data Pipelines: READY

# %%
# --- 1. Define the Embedding Engine (The "Engine" Upgrade) ---
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D, Lambda, BatchNormalization, Activation
from tensorflow.keras.applications import ResNet50

def create_embedding_engine(input_shape=(224, 224, 3), embedding_dim=128):
    """Loads ResNet50 and adds the embedding head."""
    base_model = ResNet50(
        weights='imagenet',
        include_top=False,
        input_shape=input_shape,
        pooling='avg'
    )

    # Freeze the backbone for Stage 1 training
    base_model.trainable = False

    inputs = base_model.input
    x = base_model.output
    x = BatchNormalization()(x)
    x = Dense(embedding_dim, activation=None)(x)
    outputs = Lambda(lambda v: tf.math.l2_normalize(v, axis=1))(x)

    return Model(inputs, outputs, name="Embedding_Engine")

class SiameseModel(keras.Model):
    def __init__(self, embedding, loss="euclidean", margin=0.5):
        super().__init__()
        assert loss == "euclidean" or loss == "cosine", "loss must be either 'euclidean' or 'cosine'"
        self.embedding = embedding

        anchor_input = keras.Input(name="anchor", shape=self.embedding.input_shape[1:])
        positive_input = keras.Input(name="positive", shape=self.embedding.input_shape[1:])
        negative_input = keras.Input(name="negative", shape=self.embedding.input_shape[1:])

        anchor_embedding = self.embedding(anchor_input)
        positive_embedding = self.embedding(positive_input)
        negative_embedding = self.embedding(negative_input)

        self.siamese = keras.Model(
            inputs=[anchor_input, positive_input, negative_input],
            outputs=[anchor_embedding, positive_embedding, negative_embedding],
            name="Siamese_Trainer"
        )

        self.loss_type = loss
        self.margin = margin
        self.loss_tracker = keras.metrics.Mean(name="loss")
        self.auc_metric = keras.metrics.AUC(name="auc")

    def __distance(self, anchor, other):
        if self.loss_type == "euclidean":
            return keras.ops.sum(keras.ops.square(anchor - other), axis=-1)

        # Cosine distance (1 - similarity)
        similarity = keras.ops.sum(anchor * other, axis=-1)
        return 1.0 - similarity

    def __triplet_loss(self, ap_distance, an_distance):
        return keras.ops.maximum(ap_distance - an_distance + self.margin, 0)

    def call(self, inputs):
        return self.siamese(inputs)

    def train_step(self, data):
        (anchors, positives, negatives), y = data
        with tf.GradientTape() as tape:
            anchor_emb, positive_emb, negative_emb = self([anchors, positives, negatives])
            ap_distance = self.__distance(anchor_emb, positive_emb)
            an_distance = self.__distance(anchor_emb, negative_emb)
            loss = self.__triplet_loss(ap_distance, an_distance)

        gradients = tape.gradient(loss, self.siamese.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.siamese.trainable_variables))
        self.loss_tracker.update_state(loss)
        self.auc_metric.update_state(tf.ones_like(an_distance), an_distance)
        self.auc_metric.update_state(tf.zeros_like(ap_distance), ap_distance)
        return {"loss": self.loss_tracker.result(), "auc": self.auc_metric.result()}

    def test_step(self, data):
        (anchors, positives, negatives), y = data
        anchor_emb, positive_emb, negative_emb = self([anchors, positives, negatives])
        ap_distance = self.__distance(anchor_emb, positive_emb)
        an_distance = self.__distance(anchor_emb, negative_emb)
        loss = self.__triplet_loss(ap_distance, an_distance)
        self.loss_tracker.update_state(loss)
        self.auc_metric.update_state(tf.ones_like(an_distance), an_distance)
        self.auc_metric.update_state(tf.zeros_like(ap_distance), ap_distance)
        return {"loss": self.loss_tracker.result(), "auc": self.auc_metric.result()}

    @property
    def metrics(self):
        return [self.loss_tracker, self.auc_metric]

# %%
print("--- Training Metric Learning Model (Cosine) ---")

# 1. Create the engine (backbone is frozen by default)
embedding_cosine = create_embedding_engine(input_shape=(224, 224, 3), embedding_dim=EMBEDDING_DIM)
print(f"Engine created. Trainable vars (head): {len(embedding_cosine.trainable_variables)}")

# 2. Create the SiameseModel
siamese_cosine = SiameseModel(embedding_cosine, loss="cosine", margin=MARGIN)

# 3. Compile (Stage 1 - Training the head)
siamese_cosine.compile(optimizer=keras.optimizers.Adam(0.001))

print("Training head (backbone frozen)...")
history_cosine_head = siamese_cosine.fit(
    triplets_dataset,
    validation_data=val_triplets_dataset,
    epochs=5,
    steps_per_epoch=100, # Use 100 batches per epoch for a quick test
    validation_steps=50
)

# 4. Compile (Stage 2 - Fine-tuning the whole model)
print("\nUnfreezing backbone for fine-tuning...")
# --- THIS IS THE KEY OPTIMIZATION ---
# Set the *base_model* inside the engine to trainable
siamese_cosine.embedding.layers[1].trainable = True

# CRITICAL: Re-compile with a *very* low learning rate
siamese_cosine.compile(optimizer=keras.optimizers.Adam(1e-6))

print("Fine-tuning full model (backbone unfrozen)...")
history_cosine_full = siamese_cosine.fit(
    triplets_dataset,
    validation_data=val_triplets_dataset,
    epochs=10,
    steps_per_epoch=100,
    validation_steps=50,
    callbacks=[
        keras.callbacks.ModelCheckpoint(
            "model_siamese_cosine.weights.h5",
            save_best_only=True,
            save_weights_only=True,
            monitor="val_loss"
        )
    ]
)
print("--- Metric Learning (Cosine) Training Complete ---")
# Out:
# --- Training Metric Learning Model (Cosine) ---
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Engine created. Trainable vars (head): 4
# Training head (backbone frozen)...
# Epoch 1/5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 75s 463ms/step - auc: 0.7577 - loss: 0.2915 - val_auc: 0.8076 - val_loss: 0.2303
# Epoch 2/5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 77s 775ms/step - auc: 0.7962 - loss: 0.2457 - val_auc: 0.8018 - val_loss: 0.2355
# Epoch 3/5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 38s 382ms/step - auc: 0.8073 - loss: 0.2342 - val_auc: 0.8076 - val_loss: 0.2319
# Epoch 4/5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 39s 391ms/step - auc: 0.8183 - loss: 0.2214 - val_auc: 0.8106 - val_loss: 0.2256
# Epoch 5/5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 38s 385ms/step - auc: 0.8187 - loss: 0.2230 - val_auc: 0.8475 - val_loss: 0.2042
#
# Unfreezing backbone for fine-tuning...
# Fine-tuning full model (backbone unfrozen)...
# Epoch 1/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 73s 483ms/step - auc: 0.8270 - loss: 0.2190 - val_auc: 0.8303 - val_loss: 0.2153
# Epoch 2/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 39s 393ms/step - auc: 0.8394 - loss: 0.2073 - val_auc: 0.8333 - val_loss: 0.2105
# Epoch 3/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 413ms/step - auc: 0.8294 - loss: 0.2168 - val_auc: 0.8484 - val_loss: 0.1997
# Epoch 4/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 39s 388ms/step - auc: 0.8270 - loss: 0.2150 - val_auc: 0.8358 - val_loss: 0.2169
# Epoch 5/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 38s 386ms/step - auc: 0.8285 - loss: 0.2164 - val_auc: 0.8208 - val_loss: 0.2258
# Epoch 6/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 404ms/step - auc: 0.8376 - loss: 0.2089 - val_auc: 0.8460 - val_loss: 0.1984
# Epoch 7/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 402ms/step - auc: 0.8333 - loss: 0.2124 - val_auc: 0.8227 - val_loss: 0.2196
# Epoch 8/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 39s 389ms/step - auc: 0.8221 - loss: 0.2236 - val_auc: 0.8351 - val_loss: 0.2106
# Epoch 9/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 42s 419ms/step - auc: 0.8320 - loss: 0.2092 - val_auc: 0.8414 - val_loss: 0.1977
# Epoch 10/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 38s 386ms/step - auc: 0.8300 - loss: 0.2117 - val_auc: 0.8463 - val_loss: 0.2007
# --- Metric Learning (Cosine) Training Complete ---

# %%
print("hello")
# Out:
# hello

# %%
print("--- Preparing Classification Model ---")
from tensorflow.keras.losses import SparseCategoricalCrossentropy

# --- 1. Create the data pipeline (FIX 2) ---
def preprocess_cls(image, label):
    image = tf.image.resize(image, IMAGE_SIZE)
    image = resnet50_preprocess(image)
    return image, label

def augment_and_preprocess_cls(image, label):
    image = tf.image.resize(image, IMAGE_SIZE)
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_brightness(image, max_delta=0.2)
    image = resnet50_preprocess(image)
    return image, label

cls_train_dataset_raw = image_dataset_from_directory(
    TRAIN_DIR,
    image_size=IMAGE_SIZE,
    shuffle=True,
    seed=42,
    label_mode='int', # Use 'int'
    batch_size=BATCH_SIZE
)
# Get class names before mapping and prefetching
num_classes = len(cls_train_dataset_raw.class_names)

cls_train_dataset = cls_train_dataset_raw.map(augment_and_preprocess_cls, num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)

cls_val_dataset_raw = image_dataset_from_directory(
    VAL_DIR,
    image_size=IMAGE_SIZE,
    shuffle=False,
    label_mode='int', # Use 'int'
    batch_size=BATCH_SIZE
)
# Get class names before mapping and prefetching (though not strictly needed for validation here)
# num_classes_val = len(cls_val_dataset_raw.class_names) # Can add this if needed later


cls_val_dataset = cls_val_dataset_raw.map(preprocess_cls, num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)

# --- 2. Build the Classification Model ---
# (This replaces your classification_head function)
def create_classification_model(backbone, num_classes):
    x = backbone.output
    # Removed the redundant GlobalAveragePooling2D layer
    # x = GlobalAveragePooling2D()(x) # Re-add pooling
    # This is the layer we will "steal" as the embedding
    x = Dense(1024, activation="relu", name="embedding_layer")(x)
    x = BatchNormalization()(x)
    outputs = Dense(num_classes, activation="softmax")(x)
    return Model(inputs=backbone.input, outputs=outputs)

# Create a *separate* backbone for the classifier
base_model_cls = ResNet50(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3), pooling='avg')
base_model_cls.trainable = False # Make sure it's frozen

# Get the number of classes from the training dataset


classification_model = create_classification_model(base_model_cls, num_classes)

# --- 3. Train (Stage 1: Frozen) ---
classification_model.compile(
    optimizer=keras.optimizers.Adam(0.001),
    loss=SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

print("Training classification head (backbone frozen)...")
classification_model.fit(
    cls_train_dataset,
    validation_data=cls_val_dataset,
    epochs=5,
    steps_per_epoch=100,
    validation_steps=50
)

# --- 4. Train (Stage 2: Fine-Tuning) ---
base_model_cls.trainable = True
classification_model.compile(
    optimizer=keras.optimizers.Adam(1e-6),
    loss=SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

print("Fine-tuning full classification model (backbone unfrozen)...")
classification_model.fit(
    cls_train_dataset,
    validation_data=cls_val_dataset,
    epochs=10,
    steps_per_epoch=100,
    validation_steps=50,
    callbacks=[
        keras.callbacks.ModelCheckpoint(
            "model_classification.weights.h5",
            save_best_only=True,
            save_weights_only=True,
            monitor="val_accuracy"
        )
    ]
)
print("--- Classification Training Complete ---")
# Out:
# --- Preparing Classification Model ---
# Found 380638 files belonging to 4000 classes.
# Found 8000 files belonging to 4000 classes.
# Training classification head (backbone frozen)...
# Epoch 1/5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 30s 196ms/step - accuracy: 0.0013 - loss: 8.3002 - val_accuracy: 0.0031 - val_loss: 8.4158
# Epoch 2/5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 162ms/step - accuracy: 0.0071 - loss: 8.0324 - val_accuracy: 0.0069 - val_loss: 8.0838
# Epoch 3/5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 15s 155ms/step - accuracy: 0.0081 - loss: 7.8389 - val_accuracy: 0.0050 - val_loss: 8.0479
# Epoch 4/5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 15s 153ms/step - accuracy: 0.0124 - loss: 7.6330 - val_accuracy: 0.0106 - val_loss: 7.6903
# Epoch 5/5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 15s 154ms/step - accuracy: 0.0121 - loss: 7.4129 - val_accuracy: 0.0088 - val_loss: 7.6415
# Fine-tuning full classification model (backbone unfrozen)...
# Epoch 1/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 105s 476ms/step - accuracy: 0.0263 - loss: 7.0329 - val_accuracy: 0.0113 - val_loss: 7.5649
# Epoch 2/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 39s 386ms/step - accuracy: 0.0340 - loss: 6.7715 - val_accuracy: 0.0119 - val_loss: 7.5874
# Epoch 3/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 415ms/step - accuracy: 0.0570 - loss: 6.4446 - val_accuracy: 0.0131 - val_loss: 7.6029
# Epoch 4/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 37s 369ms/step - accuracy: 0.1116 - loss: 5.9454 - val_accuracy: 0.0113 - val_loss: 7.6063
# Epoch 5/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 361ms/step - accuracy: 0.2435 - loss: 5.3135 - val_accuracy: 0.0125 - val_loss: 7.5989
# Epoch 6/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 357ms/step - accuracy: 0.0265 - loss: 7.4180 - val_accuracy: 0.0125 - val_loss: 7.5912
# Epoch 7/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 410ms/step - accuracy: 0.0137 - loss: 7.5450 - val_accuracy: 0.0119 - val_loss: 7.5826
# Epoch 8/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 412ms/step - accuracy: 0.0104 - loss: 7.4728 - val_accuracy: 0.0119 - val_loss: 7.5720
# Epoch 9/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 358ms/step - accuracy: 0.0154 - loss: 7.4636 - val_accuracy: 0.0125 - val_loss: 7.5607
# Epoch 10/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 365ms/step - accuracy: 0.0088 - loss: 7.4937 - val_accuracy: 0.0125 - val_loss: 7.5506
# --- Classification Training Complete ---

# %% [markdown]
# ## Evaluation

# %%
import tensorflow as tf
import keras
import os
import random
import numpy as np
from glob import glob
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet50 import preprocess_input as resnet50_preprocess

# --- Define project constants from your training ---
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
EMBEDDING_DIM = 128
ROOT_DIR = "/content/data/"
PAIRS_FILE = os.path.join(ROOT_DIR, "verification_pairs_val.txt")
PAIRS_BASE_DIR = ROOT_DIR
num_classes = len([name for name in os.listdir(os.path.join(ROOT_DIR, "classification_data/train_data")) if os.path.isdir(os.path.join(ROOT_DIR, "classification_data/train_data", name))])

# --- 1. Define the Verification Data Loader ---
# (This is your FaceVerificationSet class, upgraded for 224x224 and ResNet50)

class FaceVerificationSet(keras.utils.Sequence):
    def __init__(self, base_data_dir, pairs_text_path, batch_size=32, image_size=(224, 224)):
        self.base_data_dir = base_data_dir
        self.pairs_text_path = pairs_text_path
        self.batch_size = batch_size
        self.image_size = image_size
        self.batches = []

        with open(self.pairs_text_path, encoding="utf-8") as file:
            self.data = [
                {
                    # The verification file path is relative to 'data/'
                    "x1": os.path.join(base_data_dir, line.split(" ")[0]),
                    "x2": os.path.join(base_data_dir, line.split(" ")[1]),
                    "y": int(line.split(" ")[2].strip())
                }
                for line in file.readlines()
            ]

        for i in range(0, len(self.data), self.batch_size):
            self.batches.append(self.data[i:i + self.batch_size])

    def get_y(self):
        # 1 means same person, 0 means different
        return [data["y"] for data in self.data]

    def __preprocess_image(self, image_path):
        image = tf.io.read_file(image_path)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.resize(image, self.image_size) # Use 224x224
        image = resnet50_preprocess(image) # Use correct preprocessor
        return image

    def __len__(self):
        return len(self.batches)

    def __getitem__(self, idx):
        batch = self.batches[idx]
        # FIX: Return inputs as a list instead of a tuple
        return [
            tf.stack([self.__preprocess_image(data["x1"]) for data in batch]),
            tf.stack([self.__preprocess_image(data["x2"]) for data in batch])
        ]

# --- 2. Define the Distance Head ---
# (This is your distance_head function, no changes needed)
def distance_head(embedding_model, loss="euclidean"):
    input_x1 = keras.Input(name="input_x1", shape=embedding_model.input_shape[1:])
    input_x2 = keras.Input(name="input_x2", shape=embedding_model.input_shape[1:])
    x1_embedding = embedding_model(input_x1)
    x2_embedding = embedding_model(input_x2)

    if loss == "euclidean":
        distance = keras.ops.sum(keras.ops.square(x1_embedding - x2_embedding), axis=-1)
    else: # Cosine
        similarity = keras.ops.sum(x1_embedding * x2_embedding, axis=-1)
        distance = 1.0 - similarity
    return keras.Model(inputs=[input_x1, input_x2], outputs=distance)

# %%
# --- 3. (FIX 3) Load All Models *Correctly* ---
print("Loading trained models for evaluation...")

# --- Load Metric Model (Cosine) ---
# First, re-create the *exact* architecture you trained
# (We need the 'create_embedding_engine' and 'SiameseModel' classes defined in previous cells)
embedding_engine_cos = create_embedding_engine((*IMAGE_SIZE, 3), EMBEDDING_DIM)
siamese_model_cos = SiameseModel(embedding_engine_cos, "cosine", margin=MARGIN)

# Build the model by passing a dummy batch (this is a Keras requirement)
dummy_batch = (
    tf.zeros((1, *IMAGE_SIZE, 3)),
    tf.zeros((1, *IMAGE_SIZE, 3)),
    tf.zeros((1, *IMAGE_SIZE, 3))
)
_ = siamese_model_cos(dummy_batch)

# Now, load the saved weights from your training
try:
    siamese_model_cos.load_weights("model_siamese_cosine.weights.h5")
    print("Loaded 'model_siamese_cosine.weights.h5' successfully.")
except Exception as e:
    print(f"ERROR: Could not load 'model_siamese_cosine.weights.h5'. Did you run training? Error: {e}")

# Extract the *TRAINED* embedding engine (the "tower")
trained_embedding_cosine = siamese_model_cos.embedding
# Create the 2-input distance model using the *trained* engine
cosine_distance_model = distance_head(trained_embedding_cosine, loss="cosine")

# --- Load Classification Model ---
print("Loading trained Classification model...")

# Re-create the *exact* architecture
# (We need the 'create_classification_model' function defined in your training cell)
base_model_cls_eval = ResNet50(weights=None, include_top=False, input_shape=(*IMAGE_SIZE, 3), pooling='avg')
base_model_cls_eval.trainable = False # Not relevant for inference, but good practice
classification_model_eval = create_classification_model(base_model_cls_eval, num_classes)

# Build the model
_ = classification_model_eval(tf.zeros((1, *IMAGE_SIZE, 3)))

# Load the saved weights
try:
    classification_model_eval.load_weights("model_classification.weights.h5")
    print("Loaded 'model_classification.weights.h5' successfully.")
except Exception as e:
    print(f"ERROR: Could not load 'model_classification.weights.h5'. Did you run training? Error: {e}")

# Extract the *TRAINED* embedding part
# This is the layer we named "embedding_layer"
trained_embedding_classification = Model(
    inputs=classification_model_eval.input,
    outputs=classification_model_eval.get_layer("embedding_layer").output
)

# --- CRITICAL: We must L2-normalize this embedding to compare it fairly ---
# The metric model was normalized, so this one must be too.
norm_output = Lambda(lambda v: tf.math.l2_normalize(v, axis=1))(trained_embedding_classification.output)
final_cls_embedder = Model(inputs=trained_embedding_classification.input, outputs=norm_output)
# Now we create the distance head using the *same cosine distance* for a fair comparison
classification_distance_model = distance_head(final_cls_embedder, loss="cosine")
print("Loaded Classification model and extracted normalized embedding layer.")

# --- 4. Run Predictions ---
print("\nInitializing verification data loader...")
data_verification = FaceVerificationSet(PAIRS_BASE_DIR, PAIRS_FILE, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE)
y_true = data_verification.get_y() # Get all true labels (1=same, 0=different)

print("Predicting with Metric (Cosine) Model...")
# A low distance = same person. We want a high *score* for "same" (label 1).
# So, score = 1.0 - distance
scores_cosine = 1.0 - cosine_distance_model.predict(data_verification)

print("Predicting with Classification Model...")
scores_classification = 1.0 - classification_distance_model.predict(data_verification)

# --- 5. Calculate & Plot Metrics ---
auc_cosine = roc_auc_score(y_true, scores_cosine)
auc_classification = roc_auc_score(y_true, scores_classification)

print(f"\n--- FINAL RESULTS ---")
print(f"Metric Learning (Cosine) AUC: {auc_cosine:.4f}")
print(f"Classification-Based AUC:     {auc_classification:.4f}")

fpr_cos, tpr_cos, thresholds_cos = roc_curve(y_true, scores_cosine)
fpr_cls, tpr_cls, thresholds_cls = roc_curve(y_true, scores_classification)

plt.figure(figsize=(10, 7))
plt.plot(fpr_cos, tpr_cos, label=f"Metric Learning (Cosine) (AUC: {auc_cosine:.4f})")
plt.plot(fpr_cls, tpr_cls, label=f"Classification-Based (AUC: {auc_classification:.4f})")
plt.plot([0, 1], [0, 1], linestyle="--", label="No Skill (AUC: 0.50)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve: Metric Learning vs. Classification")
plt.legend()
plt.grid(True)
plt.show()

# --- 6. Find Your Optimal Threshold ---
# This is the "magic number" your app will use
# We find the point on the ROC curve closest to the top-left corner (0,1)
# (This is the J-statistic, which is TPR - FPR)
best_idx = np.argmax(tpr_cos - fpr_cos)
FINAL_THRESHOLD = thresholds_cos[best_idx]
print(f"--- Your Final Application Parameters ---")
print(f"WINNING MODEL: Metric Learning (Cosine)")
print(f"AUC SCORE: {auc_cosine:.4f}")
print(f"OPTIMAL THRESHOLD (for score > threshold): {FINAL_THRESHOLD:.4f}")
# Out:
# Loading trained models for evaluation...
# Loaded 'model_siamese_cosine.weights.h5' successfully.
# Loading trained Classification model...
# Loaded 'model_classification.weights.h5' successfully.
# Loaded Classification model and extracted normalized embedding layer.
#
# Initializing verification data loader...
# Predicting with Metric (Cosine) Model...
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-540997427.py in <cell line: 0>()
#      70 # A low distance = same person. We want a high *score* for "same" (label 1).
#      71 # So, score = 1.0 - distance
# ---> 72 scores_cosine = 1.0 - cosine_distance_model.predict(data_verification)
#      73
#      74 print("Predicting with Classification Model...")
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     158     inputs = tree.flatten(inputs)
#     159     if len(inputs) != len(input_spec):
# --> 160         raise ValueError(
#     161             f'Layer "{layer_name}" expects {len(input_spec)} input(s),'
#     162             f" but it received {len(inputs)} input tensors. "
#
# ValueError: Layer "functional_6" expects 2 input(s), but it received 1 input tensors. Inputs received: [<tf.Tensor 'data:0' shape=(32, 224, 224, 3) dtype=float32>]

# %%
# Save the Metric Learning (Cosine) embedding engine to /content
try:
    trained_embedding_cosine.save("/content/metric_learning_embedding_model_cosine.keras")
    print("Metric learning embedding model saved successfully to /content.")
except Exception as e:
    print(f"Error saving metric learning embedding model to /content: {e}")


# Save the Classification-based embedding model to /content
# try:
#     final_cls_embedder.save("/content/classification_embedding_model.keras")
#     print("Classification embedding model saved successfully to /content.")
# except Exception as e:
#     print(f"Error saving classification embedding model to /content: {e}")

# You can also save just the weights if you prefer:
# siamese_model_cos.embedding.save_weights("/content/metric_learning_embedding_weights_cosine.h5")
# final_cls_embedder.save_weights("/content/classification_embedding_weights.h5")
# Out:
# Metric learning embedding model saved successfully to /content.
